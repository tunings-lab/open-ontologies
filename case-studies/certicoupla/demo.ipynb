# %% [markdown]
# # certicoupla: joint-valid uncertainty certificates on real DFT data
#
# Independent conformal prediction gives the right per-target coverage and the **wrong joint coverage** when scientific outputs are correlated. This runs the demonstration on real OQMD materials: a frozen regressor, then independent vs coupled vs Gaussian-copula certificates, all calibrated to 90% joint coverage.
#
# **Runtime -> Run all.** Code and the fetched dataset are pulled from GitHub; nothing else to set up.
#
# Repo: https://github.com/fabio-rovai/open-ontologies/tree/main/case-studies/certicoupla

# %%
# !pip -q install numpy scipy scikit-learn requests
# !mkdir -p src data results
# !wget -q https://raw.githubusercontent.com/fabio-rovai/open-ontologies/main/case-studies/certicoupla/src/certicoupla.py -O src/certicoupla.py
# !wget -q https://raw.githubusercontent.com/fabio-rovai/open-ontologies/main/case-studies/certicoupla/data/oqmd.json -O data/oqmd.json
print('ready')

# %%
# !python src/certicoupla.py

# %% [markdown]
# ---
# Independent conformal: ~90% marginal but only ~79% joint coverage. The coupled certificate restores ~90% joint; the copula certificate matches it in a much smaller region. Write-up: https://gov.tesseract.academy/research/copula-coupled-uncertainty-certificates
